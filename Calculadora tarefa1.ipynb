# %%
nome = input("Digite seu nome: ") #Aguardar usuário digitar algo
print(nome)

# %%
numero1 = input("Digite o primero número: ") #Aguardar usuário digitar algo

tipo1 = input("Você deseja que esse número seja inteiro ou float (decimal)? ")

if tipo1 == 'inteiro':
  numero1 = int(numero1)
else:
  numero1 = float(numero1)

numero2 = input("Digite outro número: ") #Aguardar usuário digitar algo ]

tipo2 = input("Você deseja que esse número seja inteiro ou float (decimal)? ")

if tipo2 == 'inteiro':
  numero2 = int(numero2)
else:
  numero2 = float(numero2)
# Out:
# Digite o primero número: 9
# Você deseja que esse número seja inteiro ou float (decimal)? float
# Digite outro número: 3
# Você deseja que esse número seja inteiro ou float (decimal)? float

# %%
 def operaçoes_matematicas(nummero1, numero2):
  soma = numero1 + numero2
  subtraçao = numero1 - numero2
  multiplicacao = numero1 * numero2
  if numero2 != 0:
    divisao = numero1 / numero2
  else:
    divisao = "Não é possível dividir por zero"
# Imprimos os resultados das operações
print("Soma: {soma}")
print("Subtração: {subtraçao}")
print("Multiplicação: {multiplicaçao}")
print("Divisão: {divisao}")
# Out:
# Soma: {soma}
# Subtração: {subtraçao}
# Multiplicação: {multiplicaçao}
# Divisão: {divisao}

# %%
nova_operaçao = input("Deseja realizar outra operação? (Sim/Não) ")
if nova_operaçao == "não":
  print("Encerrando o programa")
# Out:
# Deseja realizar outra operação? (Sim/Não) não
# Encerrando o programa
